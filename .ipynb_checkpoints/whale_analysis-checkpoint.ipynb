# %% [markdown]
#  #  A Whale off the Port(folio)
#  ---
#
#  In this assignment, you'll get to use what you've learned this week to evaluate the performance among various algorithmic, hedge, and mutual fund portfolios and compare them against the S&P 500 Index.

# %%
# Initial imports
import pandas as pd
import numpy as np
import datetime as dt
from pathlib import Path

# %matplotlib inline

# %% [markdown]
# # Data Cleaning
#
# In this section, you will need to read the CSV files into DataFrames and perform any necessary data cleaning steps. After cleaning, combine all DataFrames into a single DataFrame.
#
# Files:
#
# * `whale_returns.csv`: Contains returns of some famous "whale" investors' portfolios.
#
# * `algo_returns.csv`: Contains returns from the in-house trading algorithms from Harold's company.
#
# * `sp500_history.csv`: Contains historical closing prices of the S&P 500 Index.

# %% [markdown]
# ## Whale Returns
#
# Read the Whale Portfolio daily returns and clean the data

# %%
# Reading whale returns
csv_path_1=Path("Resources/whale_returns.csv" )
whale_df=pd.read_csv(csv_path_1,index_col="Date", parse_dates=True,
                     infer_datetime_format=True)
whale_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-02                        NaN                 NaN
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# ...                               ...                 ...
# 2019-04-25                  -0.000285           -0.001291
# 2019-04-26                   0.008149            0.009162
# 2019-04-29                   0.001254            0.002719
# 2019-04-30                  -0.001295           -0.002211
# 2019-05-01                  -0.005847           -0.001341
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC
# Date
# 2015-03-02                          NaN                     NaN
# 2015-03-03                    -0.000496               -0.006569
# ...

# %%
# Count nulls
whale_df.isna().sum()
# Out:
# SOROS FUND MANAGEMENT LLC      1
# PAULSON & CO.INC.              1
# TIGER GLOBAL MANAGEMENT LLC    1
# BERKSHIRE HATHAWAY INC         1
# dtype: int64

# %%
# Drop nulls
whale_df=whale_df.dropna()

# %% [markdown]
# ## Algorithmic Daily Returns
#
# Read the algorithmic daily returns and clean the data

# %%
# Reading algorithmic returns
csv_path_2=Path("Resources/algo_returns.csv")
algo_df=pd.read_csv(csv_path_2,index_col="Date", parse_dates=True,
                     infer_datetime_format=True)

# %%
# Count nulls
algo_df.isna().sum()
# Out:
# Algo 1    0
# Algo 2    6
# dtype: int64

# %%
# Drop nulls
algo_df=algo_df.dropna()

# %% [markdown]
# ## S&P 500 Returns
#
# Read the S&P 500 historic closing prices and create a new daily returns DataFrame from the data.

# %%
# Reading S&P 500 Closing Prices
csv_path_3=Path("Resources/sp500_history.csv")
sp500_df=pd.read_csv(csv_path_3,index_col="Date", parse_dates=True,
                     infer_datetime_format=True)

# %%
# Check Data Types
sp500_df.dtypes
# Out:
# Close    object
# dtype: object

# %%
# Fix Data Types
sp500_df["Close"]=sp500_df["Close"].str.replace("$","",regex=True)
sp500_df["Close"]=sp500_df["Close"].astype("float")
sp500_df.dtypes
# Out:
# Close    float64
# dtype: object

# %%
# Calculate Daily Returns
daily_returns_sp500=sp500_df["Close"].pct_change()
daily_returns_sp500.head()
sp500_df["Close"]=sp500_df["Close"].pct_change()
sp500_df.head()
# Out:
#                Close
# Date
# 2019-04-23       NaN
# 2019-04-22 -0.008764
# 2019-04-18 -0.001011
# 2019-04-17 -0.001577
# 2019-04-16  0.002279

# %%
# Drop nulls
sp500_df=sp500_df.dropna()

# %%
# Rename `Close` Column to be specific to this portfolio.
sp500_df=sp500_df.rename(columns={"Close": "Close_SP500"})
sp500_df.tail()
# Out:
#             Close_SP500
# Date
# 2012-10-05     0.003469
# 2012-10-04     0.000322
# 2012-10-03    -0.007123
# 2012-10-02    -0.003611
# 2012-10-01    -0.000872

# %% [markdown]
# ## Combine Whale, Algorithmic, and S&P 500 Returns

# %%
# Join Whale Returns, Algorithmic Returns, and the S&P 500 Returns into a single DataFrame with columns for each portfolio's returns.
combined_df= pd.concat([whale_df,algo_df,sp500_df], axis = 'columns', join='inner') 
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                  -0.001266           -0.004981
# 2015-03-04                   0.002230            0.003241
# 2015-03-05                   0.004016            0.004076
# 2015-03-06                  -0.007905           -0.003574
# 2015-03-09                   0.000582            0.004225
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                    -0.000496               -0.006569 -0.001942
# 2015-03-04                    -0.002534                0.004213 -0.008589
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Conduct Quantitative Analysis
#
# In this section, you will calculate and visualize performance and risk metrics for the portfolios.

# %% [markdown]
# ## Performance Anlysis
#
# #### Calculate and Plot the daily returns.

# %%
combined_df.plot(figsize=(25,15), title="Daily returns of All Portfolios")
# Out:
# <AxesSubplot:title={'center':'Daily returns of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# #### Calculate and Plot cumulative returns.

# %%
# Calculate cumulative returns of all portfolios
# -1
cumulative_returns=(1+combined_df).cumprod()-1
cumulative_returns

# Plot cumulative returns
cumulative_returns.plot(figsize=(20,10), title="Cumulative Returns of all Portfolios")
# Out:
# <AxesSubplot:title={'center':'Cumulative Returns of all Portfolios'}, xlabel='Date'>

# %% [markdown]
# ---

# %% [markdown]
# ## Risk Analysis
#
# Determine the _risk_ of each portfolio:
#
# 1. Create a box plot for each portfolio.
# 2. Calculate the standard deviation for all portfolios
# 4. Determine which portfolios are riskier than the S&P 500
# 5. Calculate the Annualized Standard Deviation

# %% [markdown]
# ### Create a box plot for each portfolio

# %%
# Box plot to visually show risk
combined_df.boxplot(figsize=(25,10))
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### Calculate Standard Deviations

# %%
# Calculate the daily standard deviations of all portfolios
daily_std = combined_df.std() 
daily_std
# Out:
# SOROS FUND MANAGEMENT LLC      0.007896
# PAULSON & CO.INC.              0.007026
# TIGER GLOBAL MANAGEMENT LLC    0.010897
# BERKSHIRE HATHAWAY INC         0.012919
# Algo 1                         0.007623
# Algo 2                         0.008341
# Close_SP500                    0.008587
# dtype: float64

# %% [markdown]
# ### Determine which portfolios are riskier than the S&P 500

# %%
# Calculate  the daily standard deviation of S&P 500
daily_std_sp500=combined_df["Close_SP500"].std() 
daily_std_sp500
# Determine which portfolios are riskier than the S&P 500
daily_std > daily_std_sp500
# Out:
# SOROS FUND MANAGEMENT LLC      False
# PAULSON & CO.INC.              False
# TIGER GLOBAL MANAGEMENT LLC     True
# BERKSHIRE HATHAWAY INC          True
# Algo 1                         False
# Algo 2                         False
# Close_SP500                    False
# dtype: bool

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
# Calculate the annualized standard deviation (252 trading days)
annualized_std = daily_std * np.sqrt(252) 
annualized_std.head()
# Out:
# SOROS FUND MANAGEMENT LLC      0.125348
# PAULSON & CO.INC.              0.111527
# TIGER GLOBAL MANAGEMENT LLC    0.172989
# BERKSHIRE HATHAWAY INC         0.205079
# Algo 1                         0.121006
# dtype: float64

# %% [markdown]
# ---

# %% [markdown]
# ## Rolling Statistics
#
# Risk changes over time. Analyze the rolling statistics for Risk and Beta.
#
# 1. Calculate and plot the rolling standard deviation for all portfolios using a 21-day window
# 2. Calculate the correlation between each stock to determine which portfolios may mimick the S&P 500
# 3. Choose one portfolio, then calculate and plot the 60-day rolling beta between it and the S&P 500

# %% [markdown]
# ### Calculate and plot rolling `std` for all portfolios with 21-day window

# %%
# Calculate the rolling standard deviation for all portfolios using a 21-day window
# Plot the rolling standard deviation
 
combined_df.rolling(window=21).std().plot(figsize=(20,10), title="21-Day Rolling Standard Deviation of All Portfolios")
# Out:
# <AxesSubplot:title={'center':'21-Day Rolling Standard Deviation of All Portfolios'}, xlabel='Date'>

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate the correlation
correlation=combined_df.corr() 

# Display de correlation matrix
correlation
# Out:
#                              SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# SOROS FUND MANAGEMENT LLC                     1.000000            0.699823
# PAULSON & CO.INC.                             0.699823            1.000000
# TIGER GLOBAL MANAGEMENT LLC                   0.561040            0.434308
# BERKSHIRE HATHAWAY INC                        0.754157            0.545451
# Algo 1                                        0.320901            0.268631
# Algo 2                                        0.826730            0.678085
# Close_SP500                                   0.000574            0.013549
#
#                              TIGER GLOBAL MANAGEMENT LLC  \
# SOROS FUND MANAGEMENT LLC                       0.561040
# PAULSON & CO.INC.                               0.434308
# TIGER GLOBAL MANAGEMENT LLC                     1.000000
# BERKSHIRE HATHAWAY INC                          0.424125
# Algo 1                                          0.164114
# ...

# %% [markdown]
# ### Calculate and Plot Beta for a chosen portfolio and the S&P 500

# %%
# Calculate covariance of a single portfolio
covariance=combined_df["Algo 1"].rolling(window=60).cov(combined_df["Close_SP500"]) 
covariance

# Calculate variance of S&P 500
variance=combined_df["Close_SP500"].rolling(window=60).var() 
variance
                                                   
# Computing beta
algo1_beta=covariance/variance 
algo1_beta
# Out:
# Date
# 2015-03-03         NaN
# 2015-03-04         NaN
# 2015-03-05         NaN
# 2015-03-06         NaN
# 2015-03-09         NaN
#                 ...
# 2019-04-15   -0.116546
# 2019-04-16   -0.102774
# 2019-04-17   -0.101901
# 2019-04-18   -0.103039
# 2019-04-22   -0.113498
# Length: 1042, dtype: float64

# %%
# Plot beta trend
algo1_beta.plot(figsize=(20, 10), title="Rolling 60-Day Beta for Algo1 Portfolio")
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta for Algo1 Portfolio'}, xlabel='Date'>

# %% [markdown]
# ## Rolling Statistics Challenge: Exponentially Weighted Average
#
# An alternative way to calculate a rolling window is to take the exponentially weighted moving average. This is like a moving window average, but it assigns greater importance to more recent observations. Try calculating the [`ewm`](https://pandas.pydata.org/pandas-docs/stable/reference/api/pandas.DataFrame.ewm.html) with a 21-day half life for each portfolio, using standard deviation (`std`) as the metric of interest.

# %%
# Use `ewm` to calculate the rolling window
combined_df.ewm(halflife=21).std()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# Date
# 2015-03-03                        NaN                 NaN
# 2015-03-04                   0.002472            0.005814
# 2015-03-05                   0.002677            0.004968
# 2015-03-06                   0.005349            0.004615
# 2015-03-09                   0.004638            0.004471
# ...                               ...                 ...
# 2019-04-15                   0.007755            0.006960
# 2019-04-16                   0.007632            0.006846
# 2019-04-17                   0.007547            0.006846
# 2019-04-18                   0.007424            0.006737
# 2019-04-22                   0.007336            0.006764
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# Date
# 2015-03-03                          NaN                     NaN       NaN
# 2015-03-04                     0.001441                0.007624  0.004700
# ...

# %% [markdown]
# ---

# %% [markdown]
# # Sharpe Ratios
# In reality, investment managers and thier institutional investors look at the ratio of return-to-risk, and not just returns alone. After all, if you could invest in one of two portfolios, and each offered the same 10% return, yet one offered lower risk, you'd take that one, right?
#
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
#Standard deviations
combined_std=combined_df.std()
combined_std.head()

#Annualized standard deviations
annualized_std=combined_std*np.sqrt(252)
annualized_std.head()

# Annualized Sharpe Ratios
annualized_shrp_ratio=((combined_df.mean()*252)/(annualized_std))
annualized_shrp_ratio
# Out:
# SOROS FUND MANAGEMENT LLC      0.342894
# PAULSON & CO.INC.             -0.491422
# TIGER GLOBAL MANAGEMENT LLC   -0.130186
# BERKSHIRE HATHAWAY INC         0.606743
# Algo 1                         1.369589
# Algo 2                         0.484334
# Close_SP500                   -0.518582
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
annualized_shrp_ratio.plot.bar(figsize=(10,5), title="Sharpe Ratios of All Portfolios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of All Portfolios'}>

# %% [markdown]
# ### Determine whether the algorithmic strategies outperform both the market (S&P 500) and the whales portfolios.
#
# Algo1 outperforms the market and all the whale portfolios. Algo2 outperforms the market and all the whale portfolios except Berkshire Hathaway Inc.

# %% [markdown]
# ---

# %% [markdown]
# # Create Custom Portfolio
#
# In this section, you will build your own portfolio of stocks, calculate the returns, and compare the results to the Whale Portfolios and the S&P 500.
#
# 1. Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.
# 2. Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock
# 3. Join your portfolio returns to the DataFrame that contains all of the portfolio returns
# 4. Re-run the performance and risk analysis with your portfolio to see how it compares to the others
# 5. Include correlation analysis to determine which stocks (if any) are correlated

# %% [markdown]
# ## Choose 3-5 custom stocks with at last 1 year's worth of historic prices and create a DataFrame of the closing prices and dates for each stock.

# %%
# Reading data from 1st stock
csv_path_4=Path("Resources/aapl_historical.csv" )
aapl_df=pd.read_csv(csv_path_4,index_col="Trade DATE",parse_dates=True,
                     infer_datetime_format=True)
aapl_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   AAPL  200.72
# 2019-05-08   AAPL  202.90
# 2019-05-07   AAPL  202.86
# 2019-05-06   AAPL  208.48
# 2019-05-03   AAPL  211.75
# ...           ...     ...
# 2018-05-17   AAPL  186.99
# 2018-05-16   AAPL  188.18
# 2018-05-15   AAPL  186.44
# 2018-05-14   AAPL  188.15
# 2018-05-11   AAPL  188.59
#
# [250 rows x 2 columns]

# %%
#Rename close price column

aapl_df=aapl_df.rename(columns={"NOCP":"AAPL_Close"})
aapl_df.head()
# Out:
#            Symbol  AAPL_Close
# Trade DATE
# 2019-05-09   AAPL      200.72
# 2019-05-08   AAPL      202.90
# 2019-05-07   AAPL      202.86
# 2019-05-06   AAPL      208.48
# 2019-05-03   AAPL      211.75

# %%
# Reading data from 2nd stock
csv_path_5=Path("Resources/cost_historical.csv" )
cost_df=pd.read_csv(csv_path_5,index_col="Trade DATE",parse_dates=True,
                     infer_datetime_format=True)
cost_df
# Out:
#            Symbol    NOCP
# Trade DATE
# 2019-05-09   COST  243.47
# 2019-05-08   COST  241.34
# 2019-05-07   COST  240.18
# 2019-05-06   COST  244.23
# 2019-05-03   COST  244.62
# ...           ...     ...
# 2018-05-17   COST  199.60
# 2018-05-16   COST  198.71
# 2018-05-15   COST  195.48
# 2018-05-14   COST  195.88
# 2018-05-11   COST  195.76
#
# [250 rows x 2 columns]

# %%
#Rename close price column

cost_df=cost_df.rename(columns={"NOCP":"COST_Close"})
cost_df.head()
# Out:
#            Symbol  COST_Close
# Trade DATE
# 2019-05-09   COST      243.47
# 2019-05-08   COST      241.34
# 2019-05-07   COST      240.18
# 2019-05-06   COST      244.23
# 2019-05-03   COST      244.62

# %%
# Reading data from 3rd stock
csv_path_6=Path("Resources/goog_historical.csv" )
goog_df=pd.read_csv(csv_path_6,index_col="Trade DATE",parse_dates=True,
                     infer_datetime_format=True)
goog_df
# Out:
#            Symbol     NOCP
# Trade DATE
# 2019-05-09   GOOG  1162.38
# 2019-05-08   GOOG  1166.27
# 2019-05-07   GOOG  1174.10
# 2019-05-06   GOOG  1189.39
# 2019-05-03   GOOG  1185.40
# ...           ...      ...
# 2018-05-17   GOOG  1078.59
# 2018-05-16   GOOG  1081.77
# 2018-05-15   GOOG  1079.23
# 2018-05-14   GOOG  1100.20
# 2018-05-11   GOOG  1098.26
#
# [250 rows x 2 columns]

# %%
#Rename close price column

goog_df=goog_df.rename(columns={"NOCP":"GOOG_Close"})
goog_df.head()
# Out:
#            Symbol  GOOG_Close
# Trade DATE
# 2019-05-09   GOOG     1162.38
# 2019-05-08   GOOG     1166.27
# 2019-05-07   GOOG     1174.10
# 2019-05-06   GOOG     1189.39
# 2019-05-03   GOOG     1185.40

# %%
# Combine all stocks in a single DataFrame
# Reorganize portfolio data by having a column per symbol

stock_df=pd.concat([aapl_df,cost_df,goog_df],axis="columns",join="inner")
stock_df

stock_df.dtypes
# Out:
# Symbol         object
# AAPL_Close    float64
# Symbol         object
# COST_Close    float64
# Symbol         object
# GOOG_Close    float64
# dtype: object

# %%
# Reset Date index
stock_df.reset_index("Trade DATE")
# Out:
#     Trade DATE Symbol  AAPL_Close Symbol  COST_Close Symbol  GOOG_Close
# 0   2019-05-09   AAPL      200.72   COST      243.47   GOOG     1162.38
# 1   2019-05-08   AAPL      202.90   COST      241.34   GOOG     1166.27
# 2   2019-05-07   AAPL      202.86   COST      240.18   GOOG     1174.10
# 3   2019-05-06   AAPL      208.48   COST      244.23   GOOG     1189.39
# 4   2019-05-03   AAPL      211.75   COST      244.62   GOOG     1185.40
# ..         ...    ...         ...    ...         ...    ...         ...
# 245 2018-05-17   AAPL      186.99   COST      199.60   GOOG     1078.59
# 246 2018-05-16   AAPL      188.18   COST      198.71   GOOG     1081.77
# 247 2018-05-15   AAPL      186.44   COST      195.48   GOOG     1079.23
# 248 2018-05-14   AAPL      188.15   COST      195.88   GOOG     1100.20
# 249 2018-05-11   AAPL      188.59   COST      195.76   GOOG     1098.26
#
# [250 rows x 7 columns]

# %%
#Drop symbol columns 

stock_df.drop(columns=["Symbol"], inplace=True)
stock_df
# Out:
#             AAPL_Close  COST_Close  GOOG_Close
# Trade DATE
# 2019-05-09      200.72      243.47     1162.38
# 2019-05-08      202.90      241.34     1166.27
# 2019-05-07      202.86      240.18     1174.10
# 2019-05-06      208.48      244.23     1189.39
# 2019-05-03      211.75      244.62     1185.40
# ...                ...         ...         ...
# 2018-05-17      186.99      199.60     1078.59
# 2018-05-16      188.18      198.71     1081.77
# 2018-05-15      186.44      195.48     1079.23
# 2018-05-14      188.15      195.88     1100.20
# 2018-05-11      188.59      195.76     1098.26
#
# [250 rows x 3 columns]

# %%
# Calculate daily returns
daily_returns_stock=stock_df.pct_change()
daily_returns_stock
# Out:
#             AAPL_Close  COST_Close  GOOG_Close
# Trade DATE
# 2019-05-09         NaN         NaN         NaN
# 2019-05-08    0.010861   -0.008749    0.003347
# 2019-05-07   -0.000197   -0.004806    0.006714
# 2019-05-06    0.027704    0.016862    0.013023
# 2019-05-03    0.015685    0.001597   -0.003355
# ...                ...         ...         ...
# 2018-05-17    0.003650    0.003217    0.011469
# 2018-05-16    0.006364   -0.004459    0.002948
# 2018-05-15   -0.009246   -0.016255   -0.002348
# 2018-05-14    0.009172    0.002046    0.019431
# 2018-05-11    0.002339   -0.000613   -0.001763
#
# [250 rows x 3 columns]

# %%
# Drop NAs
daily_returns_stock.isnull().sum()
daily_returns_stock=daily_returns_stock.dropna()

# %%
# Display sample data
daily_returns_stock.head()
# Out:
#             AAPL_Close  COST_Close  GOOG_Close
# Trade DATE
# 2019-05-08    0.010861   -0.008749    0.003347
# 2019-05-07   -0.000197   -0.004806    0.006714
# 2019-05-06    0.027704    0.016862    0.013023
# 2019-05-03    0.015685    0.001597   -0.003355
# 2019-05-02   -0.012279   -0.007890   -0.019226

# %% [markdown]
# ## Calculate the weighted returns for the portfolio assuming an equal number of shares for each stock

# %%
# Set weights
weights = [1/3, 1/3, 1/3]

# Calculate portfolio return
stock_portfolio=daily_returns_stock.dot(weights)

# Display sample data
stock_portfolio.head()
# Out:
# Trade DATE
# 2019-05-08    0.001820
# 2019-05-07    0.000570
# 2019-05-06    0.019196
# 2019-05-03    0.004642
# 2019-05-02   -0.013131
# dtype: float64

# %% [markdown]
# ## Join your portfolio returns to the DataFrame that contains all of the portfolio returns

# %%
# Join your returns DataFrame to the original returns DataFrame
# Only compare dates where return data exists for all the stocks (drop NaNs)
combined_df=pd.concat([combined_df,stock_portfolio],axis="columns",join="inner")
combined_df
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
# ...                               ...                 ...
# 2019-04-15                  -0.001422           -0.001156
# 2019-04-16                   0.002699            0.000388
# 2019-04-17                  -0.002897           -0.006467
# 2019-04-18                   0.001448            0.001222
# 2019-04-22                  -0.002586           -0.007333
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# ...

# %%
#Rename Stock Portfolio column 

combined_df=combined_df.rename(columns={0:"Stock_Portfolio"})
combined_df.head()
# Out:
#             SOROS FUND MANAGEMENT LLC  PAULSON & CO.INC.   \
# 2018-05-11                  -0.004717            0.000982
# 2018-05-14                   0.000000            0.000000
# 2018-05-15                  -0.000726           -0.001409
# 2018-05-16                   0.008637            0.006244
# 2018-05-17                  -0.001955            0.002524
#
#             TIGER GLOBAL MANAGEMENT LLC  BERKSHIRE HATHAWAY INC    Algo 1  \
# 2018-05-11                     0.002624               -0.004125  0.000358
# 2018-05-14                     0.000000                0.000000  0.000915
# 2018-05-15                    -0.003189               -0.014606 -0.001135
# 2018-05-16                     0.005480                0.004310 -0.002326
# 2018-05-17                    -0.006267               -0.005140 -0.006949
#
#               Algo 2  Close_SP500  Stock_Portfolio
# 2018-05-11  0.000281    -0.000883        -0.000012
# 2018-05-14  0.001635     0.006889         0.010216
# ...

# %% [markdown]
# ## Re-run the risk analysis with your portfolio to see how it compares to the others

# %% [markdown]
# ### Calculate the Annualized Standard Deviation

# %%
#Calculate standard deviations
daily_std_final=combined_df.std() 
daily_std_final

# Calculate the annualized `std`
annualized_std_final=daily_std_final*np.sqrt(252) 
annualized_std_final
# Out:
# SOROS FUND MANAGEMENT LLC      0.146589
# PAULSON & CO.INC.              0.116683
# TIGER GLOBAL MANAGEMENT LLC    0.232434
# BERKSHIRE HATHAWAY INC         0.246819
# Algo 1                         0.133645
# Algo 2                         0.139204
# Close_SP500                    0.152147
# Stock_Portfolio                0.213137
# dtype: float64

# %% [markdown]
# ### Calculate and plot rolling `std` with 21-day window

# %%
# Calculate rolling standard deviation
rolling_standard_deviation=combined_df.rolling(window=21).mean().plot() 

# Plot rolling standard deviation
rolling_standard_deviation.plot()
# Out:
# []

# %% [markdown]
# ### Calculate and plot the correlation

# %%
# Calculate and plot the correlation
correlation_final=combined_df.corr() 
correlation_final.plot(figsize=(23,5), title='Correlation of the Portfolios')
# Out:
# <AxesSubplot:title={'center':'Correlation of the Portfolios'}>

# %% [markdown]
# ### Calculate and Plot Rolling 60-day Beta for Your Portfolio compared to the S&P 500

# %%
# Calculate and plot Beta

rolling_covariance=combined_df["Stock_Portfolio"].rolling(window=60).cov(combined_df["Close_SP500"]) 
rolling_covariance

rolling_variance=combined_df["Close_SP500"].rolling(window=60).var() 
rolling_variance

rolling_beta=rolling_covariance/rolling_variance
rolling_beta.plot(figsize=(20, 10), title='Rolling 60-Day Beta for your Portfolio')
# Out:
# <AxesSubplot:title={'center':'Rolling 60-Day Beta for your Portfolio'}>

# %% [markdown]
# ### Using the daily returns, calculate and visualize the Sharpe ratios using a bar plot

# %%
# Calculate Annualized Sharpe Ratios

annualized_shrp_ratio_final=((combined_df.mean()*252)/(annualized_std_final))
annualized_shrp_ratio_final
# Out:
# SOROS FUND MANAGEMENT LLC      0.344766
# PAULSON & CO.INC.              0.236041
# TIGER GLOBAL MANAGEMENT LLC   -1.052249
# BERKSHIRE HATHAWAY INC         0.085005
# Algo 1                         1.999866
# Algo 2                         0.009467
# Close_SP500                   -0.432942
# Stock_Portfolio               -0.613547
# dtype: float64

# %%
# Visualize the sharpe ratios as a bar plot
annualized_shrp_ratio_final.plot.bar(figsize=(10,5), title="Sharpe Ratios of All Portfolios")
# Out:
# <AxesSubplot:title={'center':'Sharpe Ratios of All Portfolios'}>

# %% [markdown]
# ### How does your portfolio do?
#
# The portfolio does worse than the market (SP500) on a risk adjusted basis.
